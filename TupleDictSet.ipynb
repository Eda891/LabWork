# %%
tup=(5, 10, 15, 20)
print(tup)
# Out:
# (5, 10, 15, 20)

# %%
sum=0
for i in range(len(tup)):
  sum+=tup[i]
print(sum)
# Out:
# 50

# %%
print (tup+(1, 2, 3))
# Out:
# (5, 10, 15, 20, 1, 2, 3)

# %%
tup=(5, 10, 15, 20)
print(tup*5)
# Out:
# (5, 10, 15, 20, 5, 10, 15, 20, 5, 10, 15, 20, 5, 10, 15, 20, 5, 10, 15, 20)

# %%
tup=(5, 10, 15, 20)
(a, b, c, d)=tup
print(a)
print(b)
print(c)
print(d)
# Out:
# 5
# 10
# 15
# 20

# %%
import math
for i in range(len(tup)):
   print(math.sqrt(tup[i]))
# Out:
# 2.23606797749979
# 3.1622776601683795
# 3.872983346207417
# 4.47213595499958

# %%
myList = []

# %%
elements=[5, 10, 15, 20]
for i in range(len(elements)):
    myList.append(elements[i])
print(myList)
# Out:
# [5, 10, 15, 20]

# %%
print(myList[::-1])
# Out:
# [20, 15, 10, 5]

# %%
myList.insert(2,"abc")
print(myList)
# Out:
# [5, 10, 'abc', 15, 20]

# %%
myList.pop(2)
print(myList)
# Out:
# [5, 10, 15, 20]

# %%
myList.remove(15)
print(myList)
# Out:
# [5, 10, 20]

# %%
if 15 in myList:
  print(True)
else:
  print(False)
# Out:
# False

# %%
newList=myList+['a', 'b', 'c']
print(newList)
# Out:
# [5, 10, 20, 'a', 'b', 'c']

# %%
newList.extend([1, 2, 3])
print(newList)
# Out:
# [5, 10, 20, 'a', 'b', 'c', 1, 2, 3]

# %%
myDict={'a': 'foo', 'b': [1, 2, 3, 4]}
print(myDict)
# Out:
# {'a': 'foo', 'b': [1, 2, 3, 4]}

# %%
print(myDict["b"])
# Out:
# [1, 2, 3, 4]

# %%
myDict['c']="428"
print(myDict)
# Out:
# {'a': 'foo', 'b': [1, 2, 3, 4], 'c': '428'}

# %%
myDict.pop('b')
print(myDict)
# Out:
# {'a': 'foo', 'c': '428'}

# %%
dict_keys=myDict.keys()
print(dict_keys)
# Out:
# dict_keys(['a', 'c'])

# %%
dict_values=myDict.values()
print(dict_values)
# Out:
# dict_values(['foo', '428'])

# %%
for key, value in myDict.items() :
    print (key, value)
# Out:
# a foo
# c 428

# %%
myDict.update({'e': 'elephant', 'f': 'fish'})
print(myDict)
# Out:
# {'a': 'foo', 'c': '428', 'e': 'elephant', 'f': 'fish'}

# %%
mySet1={0, 1, 2, 3, 4, 5}
print(mySet1)
# Out:
# {0, 1, 2, 3, 4, 5}

# %%
mySet2={4, 5, 6, 7, 8}
print(mySet2)
# Out:
# {4, 5, 6, 7, 8}

# %%
mySet3=mySet1.union(mySet2)
print(mySet3)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 8}

# %%
mySet3=mySet1.intersection(mySet2)
print(mySet3)
# Out:
# {4, 5}

# %%
mySet3=mySet1-mySet2
print(mySet3)
# Out:
# {0, 1, 2, 3}

# %%
mySet3=mySet1.union(mySet2)-(mySet1.intersection(mySet2))
print(mySet3)
# Out:
# {0, 1, 2, 3, 6, 7, 8}
